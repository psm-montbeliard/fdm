# %% [markdown]
# <a href="https://colab.research.google.com/github/psm-montbeliard/fdm/blob/master/entropieInformationnelle/tp_entropieInformationnelle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fondements du multimédia
# ## TP Entropie informationnelle
#
# Aymeric Bouchereau - aymeric.bouchereau@edu.univ-fcomte.fr -
# Master 1 Design / UFR STGI Montbéliard / 2020-2021
#
# [Accéder au cours Moodle](https://moodle.univ-fcomte.fr/course/view.php?id=2886)
#
# Cette séance de TP Fondements du Multimédia est consacrée à l’entropie informationnelle et
# à son implémentation en Python. Vous travaillerez avec l’environnement de développement
# Jupyter Notebook. Pour faire les exercices de cette séance, vous aurez besoin des notions vues
# en CM sur les algorithmes de codage statistique, et principalement la fiche TD « Algorithmes
# de compression statistique » :
# http://moodle.univ-fcomte.fr/mod/resource/view.php?id=300871.
#
#
# Le Notebook contenant vos exercices et vos commentaires est à rendre sur Moodle au plus
# tard le ?? (date à venir). Il doit être nommé « tp3_nom_prenom_fdm.ipynb ».

# %% [markdown]
# ### Entropie de Shannon
#
# Expliquer avec vos mots ce que permet de savoir la formule de l’entropie informationnelle énoncée par Claude Shannon en 1948.

# %% [markdown]
# *Votre explication*

# %% [markdown]
# Bonus : écrire la formule de l’entropie de Hartley dans une cellule Markdown du Notebook à
# l’aide des commandes LaTex (http://deuns.chez.com/latex/maths.html) :
# \begin{equation*}
# Votre \; code \; LaTeX \; ici
# \end{equation*}

# %% [markdown]
# ...

# %% [markdown]
# ### Appliquer la formule de l’entropie
#
# Pour écrire la formule de l’entropie en Python, vous utiliserez la fonction log2() de la
# bibliothèque Numpy : ```np.log2()```

# %% [markdown]
# Calculez l’entropie pour le jeu pile ou face avec une pièce de monnaie. Expliquez votre
# résultat.

# %% [markdown]
# Même exercice, mais en sachant que la probabilité de tomber sur face est de 0.7.

# %% [markdown]
# Que se passe-t-il si vous supprimez les signes négatifs du calcul précédent ? D’après vous, pourquoi les signes négatifs sont nécessaires ?

# %% [markdown]
# ### Nombre mystère : combien de tentatives pour le trouver ?
#
# Bob doit deviner un nombre choisi aléatoirement par un programme. Le programme demande
# à Bob de saisir un nombre et indique si celui-ci est plus grand ou plus petit que le nombre
# mystère (voir capture écran). Le jeu s’arrête quand Bob trouve le nombre mystère.
# En utilisant la formule H de Claude Shannon :
# 1. Calculez le nombre minimum de tentatives nécessaires pour trouver le nombre
# mystère lorsqu’il est compris entre 1 et 10 inclus. Affichez le résultat.
# 2. Modifiez votre programme pour qu’il demande à l’utilisateur de saisir la plus haute
# valeur possible du nombre mystère. Par exemple, si l’utilisateur saisi 100, le nombre
# mystère est compris entre 1 et 100.
# 3. Créez un graphique avec Matplotlib représentant le nombre de tentatives nécessaires
# pour chaque nombre de possibilités, sur l’intervalle [1 ;50]. Pour cela, vous devez créer
# deux tableaux Numpy : l’un contenant les valeurs sur l’axe X (les nombres de
# possibilités) et l’autre contenant sur l’axe Y (l’entropie pour chaque nombre de
# possibilités).
#
# ![Capture d’écran 2020-09-14 à 10.39.58.png](data:image/png;base64,...)

# %% [markdown]
# ### Évolution de l’entropie entre p et q
#
# Soit deux états avec les probabilités p et q telles que p+q = 1. L’objectif est de représenter
# graphiquement l’évolution de l’entropie en fonction des probabilités de p et q. La courbe sera
# dessinée sur l’intervalle [0;1].
# * Pour obtenir plusieurs valeurs de p, créez un tableau Numpy avec la fonction linspace
# (```np.linspace()```). Il faut obtenir 100 valeurs comprises entre 0.00 et 1.00 ;
# * Sachant que les valeurs de q correspondent à 1-p, créez le tableau Numpy contenant
# les valeurs de q ;
# * Dans un troisième tableau Numpy, stockez les valeurs de l’entropie pour chaque valeur
# de p et q en appliquant la formule ;
# * Dessinez la courbe de l’entropie ;
# * En observant la courbe, expliquez ce que signifient les valeurs d’entropie (axe Y) de 1,
# de 0,4 et de 0.

# %% [markdown]
# ### Codage Shannon-Fano
#
# Soit la chaîne de caractères « BABEBIBOBU ».
# * Donnez les probabilités d’apparition de chaque lettre ;
# * Calculez l’entropie informationnelle en utilisant la formule de Shannon ;
# * Appliquez l’algorithme de Shannon-Fano pour obtenir le code binaire de chaque lettre.
# Au total, combien de bits au total sont utilisés pour écrire la chaîne de caractères ?
# * Calculez le nombre de bits moyen pour écrire la chaîne de caractères et comparer
# votre résultat avec l’entropie informationnelle.
